# %%
import pandas as pd

# %%
df = pd.read_csv('JC-201901-citibike-tripdata.csv')
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df1 = pd.read_csv('JC-201902-citibike-tripdata.csv')
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
df1.count()
# Out:
# tripduration               18565
# starttime                  18565
# stoptime                   18565
# start station id           18565
# start station name         18565
# start station latitude     18565
# start station longitude    18565
# end station id             18565
# end station name           18565
# end station latitude       18565
# end station longitude      18565
# bikeid                     18565
# usertype                   18565
# birth year                 18565
# gender                     18565
# dtype: int64

# %%
df2 = pd.read_csv('JC-201903-citibike-tripdata.csv')
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
df3 = pd.read_csv('JC-201904-citibike-tripdata.csv')
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
df2.count()
# Out:
# tripduration               23606
# starttime                  23606
# stoptime                   23606
# start station id           23606
# start station name         23606
# start station latitude     23606
# start station longitude    23606
# end station id             23606
# end station name           23606
# end station latitude       23606
# end station longitude      23606
# bikeid                     23606
# usertype                   23606
# birth year                 23606
# gender                     23606
# dtype: int64

# %%
df4 = pd.read_csv('JC-201905-citibike-tripdata.csv')
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1           538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2           178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3           317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4           354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
df10 = pd.read_csv('data-cZMp8.csv')
df10.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/19                                              22145
# 1  1/2/19                                              38249
# 2  1/3/19                                              42181
# 3  1/4/19                                              44420
# 4  1/5/19                                              17636
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        44131
# 1                                        58975
# 2                                        62500
# 3                                        65739
# 4                                        24326
#
#    Total Annual Members (All Time)  \
# 0                           297823
# 1                           297908
# 2                           297976
# 3                           298017
# 4                           298048
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
df10.count()
# Out:
# Date                                                  90
# Trips over the past 24-hours (midnight to 11:59pm)    90
# Miles traveled today (midnight to 11:59 pm)           90
# Total Annual Members (All Time)                       90
# 24-Hour Passes Purchased (midnight to 11:59 pm)       90
# 3-Day Passes Purchased (midnight to 11:59 pm)         90
# dtype: int64

# %%
citibike_2019 = pd.concat([df,df1, df2, df3, df4])
citibike_2019
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# 5               737  2019-01-01 12:56:53.2040  2019-01-01 13:09:11.0400
# 6               917  2019-01-01 13:03:44.7760  2019-01-01 13:19:02.7690
# 7              3248  2019-01-01 13:12:03.1280  2019-01-01 14:06:12.0400
# 8              3168  2019-01-01 13:13:12.0450  2019-01-01 14:06:00.4110
# 9               353  2019-01-01 17:07:44.6670  2019-01-01 17:13:38.2640
# 10              503  2019-01-01 17:34:50.9580  2019-01-01 17:43:14.3190
# 11              285  2019-01-01 18:06:03.1680  2019-01-01 18:10:48.5380
# ...

# %%
citibike_2019.count()
# Out:
# tripduration               131038
# starttime                  131038
# stoptime                   131038
# start station id           131038
# start station name         131038
# start station latitude     131038
# start station longitude    131038
# end station id             131038
# end station name           131038
# end station latitude       131038
# end station longitude      131038
# bikeid                     131038
# usertype                   131038
# birth year                 131038
# gender                     131038
# dtype: int64

# %%
# Export to csv
df10.to_csv("clean_data/clean_ridership_data_2019.csv")
citibike_2019.to_csv("clean_data/citibike_data_2019.csv")
